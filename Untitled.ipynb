# %%
# %run autograder.py -q q1
# Out:
# Question q1
# ...
# *** q1) check_perceptron
# Sanity checking perceptron...
# Sanity checking perceptron weight updates...
# Sanity checking complete. Now training perceptron
# *** PASS: check_perceptron
#
# ### Question q1: 6/6 ###
#
# Finished at 15:21:54
#
# Provisional grades
# ...
# Question q1: 6/6
# ------------------
# Total: 6/6
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q2
# Out:
# Question q2
# ...
# *** q2) check_regression
# Your final loss is: 0.009999
# *** PASS: check_regression
#
# ### Question q2: 6/6 ###
#
# Finished at 16:20:38
#
# Provisional grades
# ...
# Question q2: 6/6
# ------------------
# Total: 6/6
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q3
# Out:
# Question q3
# ...
# *** q3) check_digit_classification
# 0.9554
# 0.9644
# 0.9748
# 0.9794
# 0.98
# Your final test set accuracy is: 97.880000%
# *** PASS: check_digit_classification
#
# ### Question q3: 6/6 ###
#
# Finished at 20:57:34
#
# Provisional grades
# ...
# Question q3: 6/6
# ------------------
# Total: 6/6
#
# Your grades are NOT yet registered.  To register your grades, make sure
# to follow your instructor's guidelines to receive credit on your project.

# %%
# %run autograder.py -q q4
# Out:
# Question q4
# ...
# *** q4) check_lang_id
# Alphabet: abcdefghijklmnopqrstuvwxyzáäèéêëíïñóöúüąćęłńśźż
#
# epoch 1 iteration 17 validation-accuracy 34.2%
#   colleagues English ( 25.5%)               |en 25%|es 21%|fi 14%|nl 24%|pl 15%
#   pays       English ( 22.8%) Pred: Dutch   |en 23%|es 21%|fi 14%|nl 23%|pl 19%
#   honeymoon  English ( 15.2%) Pred: Dutch   |en 15%|es 20%|fi 19%|nl 31%|pl 15%
#   cojo       Spanish ( 19.6%) Pred: Polish  |en 19%|es 20%|fi 14%|nl 22%|pl 26%
#   limpieza   Spanish ( 19.5%) Pred: Polish  |en 19%|es 19%|fi 19%|nl 19%|pl 23%
#   suceder    Spanish ( 21.1%) Pred: Dutch   |en 19%|es 21%|fi 13%|nl 27%|pl 20%
#   aikoinaan  Finnish ( 19.3%) Pred: Dutch   |en 15%|es 22%|fi 19%|nl 28%|pl 16%
#   henkeä     Finnish ( 17.5%) Pred: Dutch   |en 23%|es 18%|fi 18%|nl 25%|pl 16%
#   vähemmän   Finnish ( 19.4%) Pred: Dutch   |en 16%|es 19%|fi 19%|nl 28%|pl 17%
#   eender     Dutch   ( 26.8%)               |en 19%|es 21%|fi 14%|nl 27%|pl 20%
# ...

# %%
# %run autograder.py
# Out:
# Question q1
# ...
# *** q1) check_perceptron
# Sanity checking perceptron...
# Sanity checking perceptron weight updates...
# Sanity checking complete. Now training perceptron
# *** PASS: check_perceptron
#
# ### Question q1: 6/6 ###
#
# Question q2
# ...
# *** q2) check_regression
# Your final loss is: 0.009999
# *** PASS: check_regression
#
# ### Question q2: 6/6 ###
#
# Question q3
# ...
# *** q3) check_digit_classification
# 0.9522
# 0.9636
# 0.9658
# 0.9736
# 0.9778
# Your final test set accuracy is: 97.860000%
# *** PASS: check_digit_classification
#
# ### Question q3: 6/6 ###
#
# Question q4
# ...
# *** q4) check_lang_id
# Alphabet: abcdefghijklmnopqrstuvwxyzáäèéêëíïñóöúüąćęłńśźż
#
# epoch 1 iteration 21 validation-accuracy 28.0%
#   resolution English ( 16.8%) Pred: Dutch   |en 17%|es 13%|fi 23%|nl 26%|pl 22%
#   relaxing   English ( 16.7%) Pred: Polish  |en 17%|es 13%|fi 21%|nl 20%|pl 29%
#   distress   English ( 20.8%) Pred: Polish  |en 21%|es 22%|fi 19%|nl 15%|pl 23%
# ...
